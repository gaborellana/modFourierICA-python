# %%
import sys
sys.path.insert(0,'../src')
from utils import *
from fica import *
from eeggen import *

# %%
eegGen = EEGGenerator()
eegGen.calculate()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-22d79d6a87b8> in <module>
#       1 eegGen = EEGGenerator()
# ----> 2 eegGen.calculate()
#
# ~\Prog\modFICA\src\eeggen.py in calculate(self)
#      36             self.Sg = np.load(self.path + 'Sg.npy')
#      37         else:
# ---> 38             self._sigGen()
#      39         if self.loadMixNoiseMat:
#      40             self.NoiseMix = np.load(self.path + 'NoiseMix.npy')
#
# ~\Prog\modFICA\src\eeggen.py in _sigGen(self)
#      67             else:
#      68                 self.Sg = np.concatenate((self.Sg,aux),0)
# ---> 69         with open(self.path + 'Sg.npy', 'wb') as f:
#      70             np.save(f, self.Sg)
#      71
#
# FileNotFoundError: [Errno 2] No such file or directory: 'files/Sg.npy'

# %%
#print(eegdata.shape)
oSc, params = toSpec(eegGen.getSources(), eegGen.Fs, eegGen.minfreq, eegGen.maxfreq,4)

plt.plot(eegGen.ff, np.log(np.squeeze(np.mean(np.abs(oSc),1))))
plt.show()
del oSc

# %%
#print(eegdata.shape)
oSc, params = toSpec(eegGen.getEEG(), eegGen.Fs, eegGen.minfreq, eegGen.maxfreq,4)

plt.plot(eegGen.ff, np.log(np.squeeze(np.mean(np.abs(oSc),1))))
plt.show()
del oSc

# %%
fica = fourierICA(eegGen, 40)
fica.normSpec = False
fica.processEEGGenerator()
X = fica.getResults()
# Out:
# Outlier removal:
#  removed  353  windows
#
# 0.00014262850174673325
# 5.3521178283055804e-05
# 1.3942482795181732e-05
# 7.497751594365276e-06
# 6.842416368280091e-06
# 5.160844399831888e-06
# 2.3476589909865453e-06
# 1.883308379246884e-06
# 1.5197574396719205e-06
# 1.1469732605906557e-06
# 6.948647515159223e-07
# 5.063952894790447e-07
# 5.584841993311329e-07
# 7.081565781552612e-07
# 7.344747985360556e-07
# 7.286633814107546e-07
# 4.97790825115807e-07
# 3.0432017228410047e-07
# 2.1189827381640214e-07
# 1.8190669415218963e-07
# 1.912428443384684e-07
# 2.56981636859166e-07
# 4.121743797380617e-07
# 6.300910981860142e-07
# 7.153761792944024e-07
# 6.508946951422345e-07
# 5.099937034902524e-07
# 4.154730171013199e-07
# 3.331066377176839e-07
# 2.7238243360816483e-07
# 2.4593227077041035e-07
# 2.911400734939562e-07
# 3.579826763910887e-07
# 4.063642643492571e-07
# 4.700644854471747e-07
# 4.535426135765519e-07
# 4.0553727809200524e-07
# 3.6737510578088717e-07
# 3.122359885088244e-07
# 2.686977508270516e-07
#
# Failed to converge, results may be wrong!
#
# get results with X = fica.getResults()

# %%
fica2 = fourierICA(eegGen, 40)
fica2.normSpec = True
fica2.processEEGGenerator()
X = fica2.getResults()
# Out:
# Outlier removal:
#  removed  34  windows
#
# 0.014760849386335595
# 0.00010037162902931662
# 2.31134088573004e-05
# 7.91646456765882e-06
# 2.284254701168109e-06
# 1.040023362541831e-06
# 4.0939742118606404e-07
# 2.1343419409625142e-07
# 1.785815360033638e-07
# 1.9290377917258184e-07
# 2.915336925202183e-07
# 5.270581737715219e-07
# 6.649640467148998e-07
# 4.335464911520148e-07
# 1.822909790893945e-07
# 1.2763612389221635e-07
# 1.5820406884525795e-07
# 2.491251731573385e-07
# 7.026342736526914e-07
# 2.632844502081788e-06
# 1.3607609303800672e-06
# 1.0764881583913422e-06
# 4.333555633229125e-07
# 1.604302418689585e-07
# 1.507567564118517e-07
# 2.8670574003797356e-07
# 1.0214980685763209e-06
# 1.1484529285343825e-06
# 2.822880469377509e-07
#
# Converged.
#
# get results with X = fica.getResults()
